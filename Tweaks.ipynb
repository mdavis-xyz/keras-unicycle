# %%
import numpy as np
from multiprocessing import Pool
import gym
import os

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam

from rl.agents.dqn import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory

from gym.envs.registration import registry, register, make, spec
import gym_unicycle
#from gym import wrappers # xvfb-run -s "-screen 0 1400x900x24" python <your_script.py>
import os.path
from time import time
from statistics import mean
import pprint as pp
import json
import sys
# Out:
# Using TensorFlow backend.

# %%
ENV_NAME = 'MATTENV-v0'
register(
    id=ENV_NAME,
    entry_point='gym_unicycle.envs:UnicycleEnv',
    max_episode_steps=2000,
    reward_threshold=800.0,
)

# %%
def attempt(args):
    lr = args['lr']
    nb_steps = args['nb_steps']
    activation = args['activation']
    layerType = args['layerType']
    # Get the environment and extract the number of actions.
    env = gym.make(ENV_NAME)
    #env = wrappers.Monitor(env, './videos/' + str(time()) + '/', force=True)
    np.random.seed(123)
    env.seed(123)
    nb_actions = env.action_space.n

    print("env.observation_space.shape: " + str(env.observation_space.shape))

    # Next, we build a very simple model.
    model = Sequential()
    model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
    if layerType == 0:
        model.add(Dense(16))
        model.add(Activation(activation))
        model.add(Dense(16))
        model.add(Activation(activation))
        model.add(Dense(16))
        model.add(Activation(activation))
    elif layerType == 1:
        model.add(Dense(16))
        model.add(Activation(activation))
        model.add(Dense(13))
        model.add(Activation(activation))
        model.add(Dense(10))
        model.add(Activation(activation))
    else:
        model.add(Dense(16))
        model.add(Activation(activation))
        model.add(Dense(13))
        model.add(Activation(activation))
        model.add(Dense(3))
        model.add(Activation(activation))
    model.add(Dense(nb_actions))
    model.add(Activation('linear'))
    print(model.summary())

    # Finally, we configure and compile our agent. You can use every built-in Keras optimizer and
    # even the metrics!
    memory = SequentialMemory(limit=100000, window_length=1)
    policy = BoltzmannQPolicy()
    dqn = DQNAgent(model=model, nb_actions=nb_actions, memory=memory, nb_steps_warmup=100,
                   target_model_update=1e-2, policy=policy)
    dqn.compile(Adam(lr=1e-3), metrics=['mae'])
    if not os.path.exists(args['fnamePrefix']):
        os.makedirs(args['fnamePrefix'])
    weights_fname = '%s/weights.h5f' % args['fnamePrefix']
    if os.path.isfile(weights_fname):
        print("Loading weights from before")
        print("Skipping training")
        dqn.load_weights(weights_fname)
    else:
        # Okay, now it's time to learn something! We visualize the training here for show, but this
        # slows down training quite a lot. You can always safely abort the training prematurely using
        # Ctrl + C.
        dqn.fit(env, nb_steps=nb_steps, visualize=False, verbose=1)

        # After training is done, we save the final weights.
        dqn.save_weights(weights_fname, overwrite=True)

    # Finally, evaluate our algorithm for 5 episodes.
    env.reset()
    env.close()
    result = dqn.test(env, nb_episodes=5, visualize=False)
    means = {
        'reward': mean(result.history['episode_reward']),
        'steps': mean(result.history['nb_steps'])
            }
    json_fname = args['fnamePrefix'] + '/result.json'
    with open(json_fname,"w") as f:
            json.dump(result.history,f)
    return(means)

# %%
def attemptWrap(args):

    if not os.path.exists(args['fnamePrefix']):
        os.makedirs(args['fnamePrefix'])
    old_stdout = sys.stdout
    new_stdout_fname = args['fnamePrefix'] + '/stdout.txt'
    sys.stdout = open(new_stdout_fname,"w")
    result = attempt(args)
    sys.stdout = old_stdout
    return(result)

# %%
def mergeDicts(x,y):
    z = x.copy()   # start with x's keys and values
    z.update(y)    # modifies z with y's keys and values & returns None
    return(z)

def testMergeDict():
    a = {1:2}
    b = {'asd':123}
    z = mergeDicts(a,b)
    assert(z == {1:2,'asd':123})
    print("Test passed")
    
testMergeDict()
print("check")
# Out:
# Test passed
# check

# %%
def main():
    if not os.path.exists('results'):
        os.makedirs('results')
    args = []
    for lr in [5e-3, 2e-3, 1e-3, 5e-4, 1e-4]:
        for nb_steps in [10**x for x in range(4,7)]:
            for activation in ['tanh','relu']:
                for layerType in range(3):
                    fname = 'results/%s_%f_%d_%d/' % (ENV_NAME,lr,nb_steps,layerType)
                    arg = {
                        'lr':lr,
                        'nb_steps':nb_steps,
                        'activation':activation,
                        'layerType':layerType,
                        'fnamePrefix':fname
                        }
                    args.append(arg)

#     pp.pprint(args)
    with Pool(4) as p:
        results = p.map(attemptWrap, args)
    pp.pprint(results)
    data = [mergeDicts(a,r) for (a,r) in zip(args,results)]
    data.sort(key=lambda x: x['reward'])
    pp.pprint(data)
    return(data)

# %%
results = main()
# Out:
# /home/matthew/Documents/Projects/software/unisim/digitalOcean/cpu/env/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# /home/matthew/Documents/Projects/software/unisim/digitalOcean/cpu/env/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# /home/matthew/Documents/Projects/software/unisim/digitalOcean/cpu/env/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# /home/matthew/Documents/Projects/software/unisim/digitalOcean/cpu/env/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# [{'reward': 78.94686712717453, 'steps': 25.6},
#  {'reward': 32.10549781478155, 'steps': 10.4},
#  {'reward': 33.871938017218454, 'steps': 10.8},
#  {'reward': 65.89540354251014, 'steps': 19},
#  {'reward': 120.51817068869562, 'steps': 41},
#  {'reward': 33.60560893816412, 'steps': 10.6},
#  {'reward': 29.651334683162844, 'steps': 9.4},
#  {'reward': 76.28108349693915, 'steps': 24.8},
#  {'reward': 91.93629129337222, 'steps': 27.4},
#  {'reward': 3111.6421257208526, 'steps': 963.2},
#  {'reward': 2791.6998746946783, 'steps': 875.8},
#  {'reward': 55.44675674703746, 'steps': 16},
#  {'reward': 4512.494581348294, 'steps': 1602.6},
#  {'reward': 1000.1892970769126, 'steps': 318.8},
#  {'reward': 421.7994214732127, 'steps': 141.8},
#  {'reward': 59.093269018830654, 'steps': 18.6},
#  {'reward': 27.53499153539131, 'steps': 8.8},
#  {'reward': 47.17073816779185, 'steps': 13.8},
#  {'reward': 49.03273059059149, 'steps': 15},
#  {'reward': 50.045252091481345, 'steps': 15.4},
#  {'reward': 25.57798457206883, 'steps': 8.4},
#  {'reward': 158.0799571827353, 'steps': 55.6},
#  {'reward': 173.4298766691939, 'steps': 57.8},
#  {'reward': 27.851896223469208, 'steps': 9},
#  {'reward': 4459.145436948516, 'steps': 1528.8},
#  {'reward': 3221.109770066241, 'steps': 1125.8},
#  {'reward': 93.10849526962771, 'steps': 28.4},
#  {'reward': 35.123460831113675, 'steps': 11.2},
#  {'reward': 42.30380951269252, 'steps': 12.6},
#  {'reward': 69.51859338508494, 'steps': 19.6},
#  {'reward': 62.51481990891694, 'steps': 19.6},
#  {'reward': 29.799556716147613, 'steps': 9.6},
#  {'reward': 1601.5112801418622, 'steps': 564},
#  {'reward': 107.98878262419343, 'steps': 36.2},
#  {'reward': 175.7002670291274, 'steps': 58.2},
#  {'reward': 67.81568508566019, 'steps': 19.4},
#  {'reward': 62.188026518665296, 'steps': 18.2},
#  {'reward': 127.04095919157764, 'steps': 40.2},
#  {'reward': 28.039493698228682, 'steps': 9.2},
#  {'reward': 53.299987976854574, 'steps': 15.6},
#  {'reward': 54.199402938897556, 'steps': 15.6},
#  {'reward': 37.895474789521245, 'steps': 12},
#  {'reward': 2100.266070259099, 'steps': 713.2},
#  {'reward': 100.88461221633203, 'steps': 36},
#  {'reward': 91.37852819965552, 'steps': 29.8},
#  {'reward': 31.896171601974295, 'steps': 10.2},
#  {'reward': 3631.745495062647, 'steps': 1270.8},
#  {'reward': 32.86190387606193, 'steps': 10.4},
#  {'reward': 527.1241257048657, 'steps': 181},
#  {'reward': 3442.7779255123028, 'steps': 1175.2},
#  {'reward': 1190.410052211039, 'steps': 438},
#  {'reward': 57.918801872479264, 'steps': 17.4},
#  {'reward': 41.48563537966699, 'steps': 12.8},
#  {'reward': 71.84566987107785, 'steps': 21.6},
#  {'reward': 68.42079221212872, 'steps': 21.4},
#  {'reward': 53.981947915523165, 'steps': 16.6},
#  {'reward': 44.058076044783334, 'steps': 13.6},
#  {'reward': 114.50763736989423, 'steps': 35.8},
#  {'reward': 127.42967978243078, 'steps': 43.2},
#  {'reward': 34.16677225137636, 'steps': 11},
#  {'reward': 2621.007555970615, 'steps': 922.8},
#  {'reward': 1396.8110785175902, 'steps': 494.6},
#  {'reward': 47.25570037663906, 'steps': 15.4},
#  {'reward': 59.343115830813915, 'steps': 19},
#  {'reward': 31.055606487874037, 'steps': 10.2},
#  {'reward': 365.7509081112536, 'steps': 126.6},
#  {'reward': 44.9058408574065, 'steps': 13.4},
#  {'reward': 5292.035300737668, 'steps': 2000},
#  {'reward': 1589.251538445843, 'steps': 485.2},
#  {'reward': 110.85131420564396, 'steps': 35},
#  {'reward': 36.13597838078408, 'steps': 11.2},
#  {'reward': 48.06288195663403, 'steps': 14.6},
#  {'reward': 118.72961147088068, 'steps': 39},
#  {'reward': 58.764794351805, 'steps': 17},
#  {'reward': 36.861260520556094, 'steps': 11},
#  {'reward': 28.583410378796366, 'steps': 8.8},
#  {'reward': 59.891979000689666, 'steps': 17.2},
#  {'reward': 40.838495464891274, 'steps': 12.6},
#  {'reward': 40.6277842888722, 'steps': 13.4},
#  {'reward': 62.96072635587495, 'steps': 19.4},
#  {'reward': 181.26890179611536, 'steps': 61.4},
#  {'reward': 332.02862687923215, 'steps': 107.6},
#  {'reward': 2386.2265432624768, 'steps': 808.8},
#  {'reward': 29.59854062107008, 'steps': 9.6},
#  {'reward': 4538.691776522887, 'steps': 1521.4},
#  {'reward': 65.65491511328428, 'steps': 20.6},
#  {'reward': 3618.9297094314447, 'steps': 1206},
#  {'reward': 61.5976190716204, 'steps': 18},
#  {'reward': 135.6820051184195, 'steps': 43.4},
#  {'reward': 30.196591877689258, 'steps': 9.6}]
# [{'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_10000_2/',
#   'layerType': 2,
#   'lr': 0.002,
#   'nb_steps': 10000,
#   'reward': 25.57798457206883,
#   'steps': 8.4},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_1000000_1/',
#   'layerType': 1,
#   'lr': 0.005,
#   'nb_steps': 1000000,
#   'reward': 27.53499153539131,
#   'steps': 8.8},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_10000_2/',
#   'layerType': 2,
#   'lr': 0.002,
#   'nb_steps': 10000,
#   'reward': 27.851896223469208,
#   'steps': 9},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_10000_2/',
#   'layerType': 2,
#   'lr': 0.001,
#   'nb_steps': 10000,
#   'reward': 28.039493698228682,
#   'steps': 9.2},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_10000_0/',
#   'layerType': 0,
#   'lr': 0.0001,
#   'nb_steps': 10000,
#   'reward': 28.583410378796366,
#   'steps': 8.8},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_100000_2/',
#   'layerType': 2,
#   'lr': 0.0001,
#   'nb_steps': 100000,
#   'reward': 29.59854062107008,
#   'steps': 9.6},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_100000_0/',
#   'layerType': 0,
#   'lr': 0.005,
#   'nb_steps': 100000,
#   'reward': 29.651334683162844,
#   'steps': 9.4},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_1000000_1/',
#   'layerType': 1,
#   'lr': 0.002,
#   'nb_steps': 1000000,
#   'reward': 29.799556716147613,
#   'steps': 9.6},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_1000000_2/',
#   'layerType': 2,
#   'lr': 0.0001,
#   'nb_steps': 1000000,
#   'reward': 30.196591877689258,
#   'steps': 9.6},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_100000_1/',
#   'layerType': 1,
#   'lr': 0.0005,
#   'nb_steps': 100000,
#   'reward': 31.055606487874037,
#   'steps': 10.2},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_100000_0/',
#   'layerType': 0,
#   'lr': 0.001,
#   'nb_steps': 100000,
#   'reward': 31.896171601974295,
#   'steps': 10.2},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_10000_1/',
#   'layerType': 1,
#   'lr': 0.005,
#   'nb_steps': 10000,
#   'reward': 32.10549781478155,
#   'steps': 10.4},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_100000_2/',
#   'layerType': 2,
#   'lr': 0.001,
#   'nb_steps': 100000,
#   'reward': 32.86190387606193,
#   'steps': 10.4},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_10000_2/',
#   'layerType': 2,
#   'lr': 0.005,
#   'nb_steps': 10000,
#   'reward': 33.60560893816412,
#   'steps': 10.6},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_10000_2/',
#   'layerType': 2,
#   'lr': 0.005,
#   'nb_steps': 10000,
#   'reward': 33.871938017218454,
#   'steps': 10.8},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_10000_2/',
#   'layerType': 2,
#   'lr': 0.0005,
#   'nb_steps': 10000,
#   'reward': 34.16677225137636,
#   'steps': 11},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_100000_0/',
#   'layerType': 0,
#   'lr': 0.002,
#   'nb_steps': 100000,
#   'reward': 35.123460831113675,
#   'steps': 11.2},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_1000000_1/',
#   'layerType': 1,
#   'lr': 0.0005,
#   'nb_steps': 1000000,
#   'reward': 36.13597838078408,
#   'steps': 11.2},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_10000_2/',
#   'layerType': 2,
#   'lr': 0.0001,
#   'nb_steps': 10000,
#   'reward': 36.861260520556094,
#   'steps': 11},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_10000_2/',
#   'layerType': 2,
#   'lr': 0.001,
#   'nb_steps': 10000,
#   'reward': 37.895474789521245,
#   'steps': 12},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_100000_0/',
#   'layerType': 0,
#   'lr': 0.0001,
#   'nb_steps': 100000,
#   'reward': 40.6277842888722,
#   'steps': 13.4},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_10000_2/',
#   'layerType': 2,
#   'lr': 0.0001,
#   'nb_steps': 10000,
#   'reward': 40.838495464891274,
#   'steps': 12.6},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_1000000_1/',
#   'layerType': 1,
#   'lr': 0.001,
#   'nb_steps': 1000000,
#   'reward': 41.48563537966699,
#   'steps': 12.8},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_100000_1/',
#   'layerType': 1,
#   'lr': 0.002,
#   'nb_steps': 100000,
#   'reward': 42.30380951269252,
#   'steps': 12.6},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_10000_2/',
#   'layerType': 2,
#   'lr': 0.0005,
#   'nb_steps': 10000,
#   'reward': 44.058076044783334,
#   'steps': 13.6},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_1000000_0/',
#   'layerType': 0,
#   'lr': 0.0005,
#   'nb_steps': 1000000,
#   'reward': 44.9058408574065,
#   'steps': 13.4},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_1000000_2/',
#   'layerType': 2,
#   'lr': 0.005,
#   'nb_steps': 1000000,
#   'reward': 47.17073816779185,
#   'steps': 13.8},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_100000_2/',
#   'layerType': 2,
#   'lr': 0.0005,
#   'nb_steps': 100000,
#   'reward': 47.25570037663906,
#   'steps': 15.4},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_1000000_2/',
#   'layerType': 2,
#   'lr': 0.0005,
#   'nb_steps': 1000000,
#   'reward': 48.06288195663403,
#   'steps': 14.6},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_10000_0/',
#   'layerType': 0,
#   'lr': 0.002,
#   'nb_steps': 10000,
#   'reward': 49.03273059059149,
#   'steps': 15},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_10000_1/',
#   'layerType': 1,
#   'lr': 0.002,
#   'nb_steps': 10000,
#   'reward': 50.045252091481345,
#   'steps': 15.4},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_10000_0/',
#   'layerType': 0,
#   'lr': 0.001,
#   'nb_steps': 10000,
#   'reward': 53.299987976854574,
#   'steps': 15.6},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_10000_1/',
#   'layerType': 1,
#   'lr': 0.0005,
#   'nb_steps': 10000,
#   'reward': 53.981947915523165,
#   'steps': 16.6},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_10000_1/',
#   'layerType': 1,
#   'lr': 0.001,
#   'nb_steps': 10000,
#   'reward': 54.199402938897556,
#   'steps': 15.6},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_100000_2/',
#   'layerType': 2,
#   'lr': 0.005,
#   'nb_steps': 100000,
#   'reward': 55.44675674703746,
#   'steps': 16},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_1000000_0/',
#   'layerType': 0,
#   'lr': 0.001,
#   'nb_steps': 1000000,
#   'reward': 57.918801872479264,
#   'steps': 17.4},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_10000_1/',
#   'layerType': 1,
#   'lr': 0.0001,
#   'nb_steps': 10000,
#   'reward': 58.764794351805,
#   'steps': 17},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_1000000_0/',
#   'layerType': 0,
#   'lr': 0.005,
#   'nb_steps': 1000000,
#   'reward': 59.093269018830654,
#   'steps': 18.6},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_100000_0/',
#   'layerType': 0,
#   'lr': 0.0005,
#   'nb_steps': 100000,
#   'reward': 59.343115830813915,
#   'steps': 19},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_10000_1/',
#   'layerType': 1,
#   'lr': 0.0001,
#   'nb_steps': 10000,
#   'reward': 59.891979000689666,
#   'steps': 17.2},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_1000000_0/',
#   'layerType': 0,
#   'lr': 0.0001,
#   'nb_steps': 1000000,
#   'reward': 61.5976190716204,
#   'steps': 18},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_10000_0/',
#   'layerType': 0,
#   'lr': 0.001,
#   'nb_steps': 10000,
#   'reward': 62.188026518665296,
#   'steps': 18.2},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_1000000_0/',
#   'layerType': 0,
#   'lr': 0.002,
#   'nb_steps': 1000000,
#   'reward': 62.51481990891694,
#   'steps': 19.6},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_100000_1/',
#   'layerType': 1,
#   'lr': 0.0001,
#   'nb_steps': 100000,
#   'reward': 62.96072635587495,
#   'steps': 19.4},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_1000000_1/',
#   'layerType': 1,
#   'lr': 0.0001,
#   'nb_steps': 1000000,
#   'reward': 65.65491511328428,
#   'steps': 20.6},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_10000_0/',
#   'layerType': 0,
#   'lr': 0.005,
#   'nb_steps': 10000,
#   'reward': 65.89540354251014,
#   'steps': 19},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_1000000_2/',
#   'layerType': 2,
#   'lr': 0.002,
#   'nb_steps': 1000000,
#   'reward': 67.81568508566019,
#   'steps': 19.4},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_10000_0/',
#   'layerType': 0,
#   'lr': 0.0005,
#   'nb_steps': 10000,
#   'reward': 68.42079221212872,
#   'steps': 21.4},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_100000_2/',
#   'layerType': 2,
#   'lr': 0.002,
#   'nb_steps': 100000,
#   'reward': 69.51859338508494,
#   'steps': 19.6},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_1000000_2/',
#   'layerType': 2,
#   'lr': 0.001,
#   'nb_steps': 1000000,
#   'reward': 71.84566987107785,
#   'steps': 21.6},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_100000_1/',
#   'layerType': 1,
#   'lr': 0.005,
#   'nb_steps': 100000,
#   'reward': 76.28108349693915,
#   'steps': 24.8},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_10000_0/',
#   'layerType': 0,
#   'lr': 0.005,
#   'nb_steps': 10000,
#   'reward': 78.94686712717453,
#   'steps': 25.6},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_100000_2/',
#   'layerType': 2,
#   'lr': 0.001,
#   'nb_steps': 100000,
#   'reward': 91.37852819965552,
#   'steps': 29.8},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_100000_2/',
#   'layerType': 2,
#   'lr': 0.005,
#   'nb_steps': 100000,
#   'reward': 91.93629129337222,
#   'steps': 27.4},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_100000_2/',
#   'layerType': 2,
#   'lr': 0.002,
#   'nb_steps': 100000,
#   'reward': 93.10849526962771,
#   'steps': 28.4},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_100000_1/',
#   'layerType': 1,
#   'lr': 0.001,
#   'nb_steps': 100000,
#   'reward': 100.88461221633203,
#   'steps': 36},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_1000000_0/',
#   'layerType': 0,
#   'lr': 0.002,
#   'nb_steps': 1000000,
#   'reward': 107.98878262419343,
#   'steps': 36.2},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_1000000_0/',
#   'layerType': 0,
#   'lr': 0.0005,
#   'nb_steps': 1000000,
#   'reward': 110.85131420564396,
#   'steps': 35},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_10000_0/',
#   'layerType': 0,
#   'lr': 0.0005,
#   'nb_steps': 10000,
#   'reward': 114.50763736989423,
#   'steps': 35.8},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_10000_0/',
#   'layerType': 0,
#   'lr': 0.0001,
#   'nb_steps': 10000,
#   'reward': 118.72961147088068,
#   'steps': 39},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_10000_1/',
#   'layerType': 1,
#   'lr': 0.005,
#   'nb_steps': 10000,
#   'reward': 120.51817068869562,
#   'steps': 41},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_10000_1/',
#   'layerType': 1,
#   'lr': 0.001,
#   'nb_steps': 10000,
#   'reward': 127.04095919157764,
#   'steps': 40.2},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_10000_1/',
#   'layerType': 1,
#   'lr': 0.0005,
#   'nb_steps': 10000,
#   'reward': 127.42967978243078,
#   'steps': 43.2},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_1000000_1/',
#   'layerType': 1,
#   'lr': 0.0001,
#   'nb_steps': 1000000,
#   'reward': 135.6820051184195,
#   'steps': 43.4},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_10000_0/',
#   'layerType': 0,
#   'lr': 0.002,
#   'nb_steps': 10000,
#   'reward': 158.0799571827353,
#   'steps': 55.6},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_10000_1/',
#   'layerType': 1,
#   'lr': 0.002,
#   'nb_steps': 10000,
#   'reward': 173.4298766691939,
#   'steps': 57.8},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_1000000_1/',
#   'layerType': 1,
#   'lr': 0.002,
#   'nb_steps': 1000000,
#   'reward': 175.7002670291274,
#   'steps': 58.2},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_100000_2/',
#   'layerType': 2,
#   'lr': 0.0001,
#   'nb_steps': 100000,
#   'reward': 181.26890179611536,
#   'steps': 61.4},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_100000_0/',
#   'layerType': 0,
#   'lr': 0.0001,
#   'nb_steps': 100000,
#   'reward': 332.02862687923215,
#   'steps': 107.6},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_100000_2/',
#   'layerType': 2,
#   'lr': 0.0005,
#   'nb_steps': 100000,
#   'reward': 365.7509081112536,
#   'steps': 126.6},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_1000000_2/',
#   'layerType': 2,
#   'lr': 0.005,
#   'nb_steps': 1000000,
#   'reward': 421.7994214732127,
#   'steps': 141.8},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_1000000_0/',
#   'layerType': 0,
#   'lr': 0.001,
#   'nb_steps': 1000000,
#   'reward': 527.1241257048657,
#   'steps': 181},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_1000000_1/',
#   'layerType': 1,
#   'lr': 0.005,
#   'nb_steps': 1000000,
#   'reward': 1000.1892970769126,
#   'steps': 318.8},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_1000000_2/',
#   'layerType': 2,
#   'lr': 0.001,
#   'nb_steps': 1000000,
#   'reward': 1190.410052211039,
#   'steps': 438},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_100000_1/',
#   'layerType': 1,
#   'lr': 0.0005,
#   'nb_steps': 100000,
#   'reward': 1396.8110785175902,
#   'steps': 494.6},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_1000000_2/',
#   'layerType': 2,
#   'lr': 0.0005,
#   'nb_steps': 1000000,
#   'reward': 1589.251538445843,
#   'steps': 485.2},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_1000000_2/',
#   'layerType': 2,
#   'lr': 0.002,
#   'nb_steps': 1000000,
#   'reward': 1601.5112801418622,
#   'steps': 564},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_100000_0/',
#   'layerType': 0,
#   'lr': 0.001,
#   'nb_steps': 100000,
#   'reward': 2100.266070259099,
#   'steps': 713.2},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_100000_1/',
#   'layerType': 1,
#   'lr': 0.0001,
#   'nb_steps': 100000,
#   'reward': 2386.2265432624768,
#   'steps': 808.8},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_100000_0/',
#   'layerType': 0,
#   'lr': 0.0005,
#   'nb_steps': 100000,
#   'reward': 2621.007555970615,
#   'steps': 922.8},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_100000_1/',
#   'layerType': 1,
#   'lr': 0.005,
#   'nb_steps': 100000,
#   'reward': 2791.6998746946783,
#   'steps': 875.8},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_100000_0/',
#   'layerType': 0,
#   'lr': 0.005,
#   'nb_steps': 100000,
#   'reward': 3111.6421257208526,
#   'steps': 963.2},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_100000_1/',
#   'layerType': 1,
#   'lr': 0.002,
#   'nb_steps': 100000,
#   'reward': 3221.109770066241,
#   'steps': 1125.8},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_1000000_1/',
#   'layerType': 1,
#   'lr': 0.001,
#   'nb_steps': 1000000,
#   'reward': 3442.7779255123028,
#   'steps': 1175.2},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_1000000_2/',
#   'layerType': 2,
#   'lr': 0.0001,
#   'nb_steps': 1000000,
#   'reward': 3618.9297094314447,
#   'steps': 1206},
#  {'activation': 'relu',
#   'fnamePrefix': 'results/MATTENV-v0_0.001000_100000_1/',
#   'layerType': 1,
#   'lr': 0.001,
#   'nb_steps': 100000,
#   'reward': 3631.745495062647,
#   'steps': 1270.8},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.002000_100000_0/',
#   'layerType': 0,
#   'lr': 0.002,
#   'nb_steps': 100000,
#   'reward': 4459.145436948516,
#   'steps': 1528.8},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.005000_1000000_0/',
#   'layerType': 0,
#   'lr': 0.005,
#   'nb_steps': 1000000,
#   'reward': 4512.494581348294,
#   'steps': 1602.6},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000100_1000000_0/',
#   'layerType': 0,
#   'lr': 0.0001,
#   'nb_steps': 1000000,
#   'reward': 4538.691776522887,
#   'steps': 1521.4},
#  {'activation': 'tanh',
#   'fnamePrefix': 'results/MATTENV-v0_0.000500_1000000_1/',
#   'layerType': 1,
#   'lr': 0.0005,
#   'nb_steps': 1000000,
#   'reward': 5292.035300737668,
#   'steps': 2000}]
